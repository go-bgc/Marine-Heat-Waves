# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
import glob
import pandas as pd
from scipy.interpolate import griddata

import sys
sys.path.append('../Zack/')
from zack_functions import find_bloom_phenological_indices

# %%
biomes = xr.open_dataset('biomes_2010_2025.nc')
biomes.close()

# %%
mhw_dates = pd.read_csv('../../MHW_list.csv')
mhw = 'NA 2023'
lon0, lon1, lat0, lat1 = mhw_dates.loc[(mhw_dates.loc[:,'name']==mhw), ['lon0','lon1','lat0','lat1']].values[0,:]

# %%
year = 2023


soca_dir = '/Volumes/FATDATABABY/copernicus/bgc-chl-poc/'
soca_version = 'P202511'


flist = sorted(glob.glob(soca_dir+'cmems_obs-mob_glo_bgc-chl-poc_my_0.25deg_P7D-m_*'+str(int(year))+'*_'+soca_version+'.nc'))
data = xr.open_mfdataset(flist)
data.close()

# %%
lon_inds = np.where((data.longitude.values>=lon0) & (data.longitude.values<=lon1))[0]
lat_inds = np.where((data.latitude.values>=lat0) & (data.latitude.values<=lat1))[0]

# Subset just to surface
# This will need to be updated if we want to keep depth resolved
data = data.isel(longitude = lon_inds, latitude = lat_inds, depth = 0)

XX_SOCA, YY_SOCA = np.meshgrid(data.longitude.values, data.latitude.values)

# %%
# re-grid biome flags
XX_biome, YY_biome = np.meshgrid(biomes.lon.values, biomes.lat.values)
points = (XX_biome.flatten(), YY_biome.flatten())

biome_flags = griddata(points, 
                       biomes.Biomes.values[np.where(biomes.year.values==year)[0],:,:].flatten(), 
               (XX_SOCA, YY_SOCA), method='nearest').reshape(XX_SOCA.shape)
biome_flags = biome_flags.reshape(XX_SOCA.shape)

# %%
ri = 160; ci = 70
plt.pcolormesh(XX_SOCA, YY_SOCA, data.chl[30,:,:])
plt.scatter(XX_SOCA[ri,ci], YY_SOCA[ri,ci])

# %%
var_names = ['PRES', 'TEMP', 'PSAL', 'DOXY', 'CHLA', 'BBP700', 'LATITUDE', 'LONGITUDE', 'JULD']

# Load chlorophyll into memory
chlorophyll = data.chl.values
# plt.plot(data.time.values, bloom_slice)
for ri in np.arange(data.latitude.shape[0]):

    print(ri, data.latitude.shape[0])
    for ci in np.arange(data.longitude.shape[0]):

        df = pd.DataFrame({'CHLA': chlorophyll[:,ri,ci],
                                    'JULD': data.time.values})
        df = df.loc[(df.loc[:,'CHLA'].isna()==False), :]

        results =  find_bloom_phenological_indices(df, var_names)
        results = results.drop(columns=["BLOOM_SLICE"])

        # print('start')
        if (ri == 0) and (ci == 0):
            df_all = results
        else:
            df_all = pd.concat((df_all, results))

        # print('end')
# Out:
# 0 200
# 1 200
# 2 200
# 3 200
# 4 200
# 5 200
# 6 200
# 7 200
# 8 200
# 9 200
# 10 200
# 11 200
# 12 200
# 13 200
# 14 200
# 15 200
# 16 200
# 17 200
# 18 200
# 19 200
# 20 200
# 21 200
# 22 200
# 23 200
# 24 200
# 25 200
# 26 200
# 27 200
# 28 200
# 29 200
# 30 200
# 31 200
# 32 200
# 33 200
# 34 200
# 35 200
# 36 200
# 37 200
# 38 200
# 39 200
# 40 200
# 41 200
# 42 200
# 43 200
# 44 200
# 45 200
# 46 200
# 47 200
# 48 200
# 49 200
# 50 200
# 51 200
# 52 200
# 53 200
# 54 200
# 55 200
# 56 200
# 57 200
# 58 200
# 59 200
# 60 200
# 61 200
# 62 200
# 63 200
# 64 200
# 65 200
# 66 200
# 67 200
# 68 200
# 69 200
# 70 200
# 71 200
# 72 200
# 73 200
# 74 200
# 75 200
# 76 200
# 77 200
# 78 200
# 79 200
# 80 200
# 81 200
# 82 200
# 83 200
# 84 200
# 85 200
# 86 200
# 87 200
# 88 200
# 89 200
# 90 200
# 91 200
# 92 200
# 93 200
# 94 200
# 95 200
# 96 200
# 97 200
# 98 200
# 99 200
# 100 200
# 101 200
# 102 200
# 103 200
# 104 200
# 105 200
# 106 200
# 107 200
# 108 200
# 109 200
# 110 200
# 111 200
# 112 200
# 113 200
# 114 200
# 115 200
# 116 200
# 117 200
# 118 200
# 119 200
# 120 200
# 121 200
# 122 200
# 123 200
# 124 200
# 125 200
# 126 200
# 127 200
# 128 200
# 129 200
# 130 200
# 131 200
# 132 200
# 133 200
# 134 200
# 135 200
# 136 200
# 137 200
# 138 200
# 139 200
# 140 200
# 141 200
# 142 200
# 143 200
# 144 200
# 145 200
# 146 200
# 147 200
# 148 200
# 149 200
# 150 200
# 151 200
# 152 200
# 153 200
# 154 200
# 155 200
# 156 200
# 157 200
# 158 200
# 159 200
# 160 200
# 161 200
# 162 200
# 163 200
# 164 200
# 165 200
# 166 200
# 167 200
# 168 200
# 169 200
# 170 200
# 171 200
# 172 200
# 173 200
# 174 200
# 175 200
# 176 200
# 177 200
# 178 200
# 179 200
# 180 200
# 181 200
# 182 200
# 183 200
# 184 200
# 185 200
# 186 200
# 187 200
# 188 200
# 189 200
# 190 200
# 191 200
# 192 200
# 193 200
# 194 200
# 195 200
# 196 200
# 197 200
# 198 200
# 199 200

# %%
data
# Out:
# <xarray.Dataset> Size: 116MB
# Dimensions:      (time: 52, latitude: 200, longitude: 200)
# Coordinates:
#   * time         (time) datetime64[ns] 416B 2023-01-04 2023-01-11 ... 2023-12-27
#   * latitude     (latitude) float32 800B 10.12 10.38 10.62 ... 59.38 59.62 59.88
#   * longitude    (longitude) float32 800B -59.88 -59.62 -59.38 ... -10.38 -10.12
#     depth        int16 2B 0
# Data variables: (12/14)
#     chl          (time, latitude, longitude) float32 8MB dask.array<chunksize=(1, 200, 200), meta=np.ndarray>
#     chl_error    (time, latitude, longitude) float32 8MB dask.array<chunksize=(1, 200, 200), meta=np.ndarray>
#     bbp          (time, latitude, longitude) float32 8MB dask.array<chunksize=(1, 200, 200), meta=np.ndarray>
#     bbp_error    (time, latitude, longitude) float32 8MB dask.array<chunksize=(1, 200, 200), meta=np.ndarray>
#     poc          (time, latitude, longitude) float32 8MB dask.array<chunksize=(1, 200, 200), meta=np.ndarray>
#     poc_error    (time, latitude, longitude) float32 8MB dask.array<chunksize=(1, 200, 200), meta=np.ndarray>
#     ...           ...
#     ED380        (time, latitude, longitude) float32 8MB dask.array<chunksize=(1, 200, 200), meta=np.ndarray>
#     ED380_error  (time, latitude, longitude) float32 8MB dask.array<chunksize=(1, 200, 200), meta=np.ndarray>
#     ED412        (time, latitude, longitude) float32 8MB dask.array<chunksize=(1, 200, 200), meta=np.ndarray>
#     ED412_error  (time, latitude, longitude) float32 8MB dask.array<chunksize=(1, 200, 200), meta=np.ndarray>
#     ED490        (time, latitude, longitude) float32 8MB dask.array<chunksize=(1, 200, 200), meta=np.ndarray>
#     ED490_error  (time, latitude, longitude) float32 8MB dask.array<chunksize=(1, 200, 200), meta=np.ndarray>
# Attributes:
#     title:        Global Ocean 3D Chlorophyll-a concentration, Particulate Ba...
#     project:      CMEMS - MULTIOBS Thematic Assembly Center
#     project_url:  http://marine.copernicus.eu
#     contact:      servicedesk.cmems@mercator-ocean.eu
#     description:  CMEMS MULTIOBS 3D BGC weekly global product estimated from ...
#     Conventions:  CF-1.6
#     institution:  LOV/IMEV/CNRS
#     domain_name:  GLO
#     references:   Sauzede et al. 2016 (Journal of Geophysical Research; https...

# %%
columns = ['BLOOM_MAXIMUM', 'BLOOM_INITIATION_TS', 'BLOOM_TERMINATION_TS', 'BLOOM_DURATION_TS',
       'BLOOM_INITIATION_TS_DATE', 'BLOOM_TERMINATION_TS_DATE',
       'BLOOM_INITIATION_CS', 'BLOOM_TERMINATION_CS', 'BLOOM_DURATION_CS',
       'BLOOM_INITIATION_CS_DATE', 'BLOOM_TERMINATION_CS_DATE',
       'BLOOM_INITIATION_RC', 'BLOOM_TERMINATION_RC', 'BLOOM_DURATION_RC',
       'BLOOM_INITIATION_RC_DATE', 'BLOOM_TERMINATION_RC_DATE']

# %%
for name in columns:
    bloom_values = df_all.loc[:,name].values.astype('float64')
    bloom_values = bloom_values.reshape(XX_SOCA.shape)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 2
#       1 for name in columns:
# ----> 2     bloom_values = df_all.loc[:,name].values.astype('float64')
#       3     bloom_values = bloom_values.reshape(XX_SOCA.shape)
#
# TypeError: float() argument must be a string or a real number, not 'Timestamp'

# %%
df_all.loc[:,name].values.astype('datetime64[D]')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 df_all.loc[:,name].values.astype('datetime64[D]')
#
# ValueError: Could not convert object to NumPy datetime

# %%
data[name] = (['latitude','longitude'], bloom_values)

# %%
data
# Out:
# <xarray.Dataset> Size: 117MB
# Dimensions:                   (time: 52, latitude: 200, longitude: 200)
# Coordinates:
#   * time                      (time) datetime64[ns] 416B 2023-01-04 ... 2023-...
#   * latitude                  (latitude) float32 800B 10.12 10.38 ... 59.88
#   * longitude                 (longitude) float32 800B -59.88 -59.62 ... -10.12
#     depth                     int16 2B 0
# Data variables: (12/15)
#     chl                       (time, latitude, longitude) float32 8MB dask.array<chunksize=(1, 200, 200), meta=np.ndarray>
#     chl_error                 (time, latitude, longitude) float32 8MB dask.array<chunksize=(1, 200, 200), meta=np.ndarray>
#     bbp                       (time, latitude, longitude) float32 8MB dask.array<chunksize=(1, 200, 200), meta=np.ndarray>
#     bbp_error                 (time, latitude, longitude) float32 8MB dask.array<chunksize=(1, 200, 200), meta=np.ndarray>
#     poc                       (time, latitude, longitude) float32 8MB dask.array<chunksize=(1, 200, 200), meta=np.ndarray>
#     poc_error                 (time, latitude, longitude) float32 8MB dask.array<chunksize=(1, 200, 200), meta=np.ndarray>
#     ...                        ...
#     ED380_error               (time, latitude, longitude) float32 8MB dask.array<chunksize=(1, 200, 200), meta=np.ndarray>
#     ED412                     (time, latitude, longitude) float32 8MB dask.array<chunksize=(1, 200, 200), meta=np.ndarray>
#     ED412_error               (time, latitude, longitude) float32 8MB dask.array<chunksize=(1, 200, 200), meta=np.ndarray>
#     ED490                     (time, latitude, longitude) float32 8MB dask.array<chunksize=(1, 200, 200), meta=np.ndarray>
#     ED490_error               (time, latitude, longitude) float32 8MB dask.array<chunksize=(1, 200, 200), meta=np.ndarray>
#     BLOOM_INITIATION_TS_DATE  (latitude, longitude) float64 320kB nan ... nan
# Attributes:
#     title:        Global Ocean 3D Chlorophyll-a concentration, Particulate Ba...
#     project:      CMEMS - MULTIOBS Thematic Assembly Center
#     project_url:  http://marine.copernicus.eu
#     contact:      servicedesk.cmems@mercator-ocean.eu
#     description:  CMEMS MULTIOBS 3D BGC weekly global product estimated from ...
#     Conventions:  CF-1.6
#     institution:  LOV/IMEV/CNRS
#     domain_name:  GLO
#     references:   Sauzede et al. 2016 (Journal of Geophysical Research; https...

# %%
test = df_all.loc[:,'BLOOM_DURATION_RC'].values.astype('float64')
test = test.reshape(XX_SOCA.shape)
plt.pcolormesh(XX_SOCA, YY_SOCA, test)
plt.colorbar()

# %%
df_all.loc[:,'BLOOM_INITIATION_TS'].values.astype('float64')
# Out:
# array([       nan, 0.09995739, 0.22512577, ..., 0.14650935, 0.21627219,
#        0.20711194], shape=(40000,))

# %%
# For each pixel,
XX_SOCA, YY_SOCA = np.meshgrid((((360 + (data.longitude.values % 360)) % 360)), data.latitude.values)

# %%
oisst_path = '../../../gobgc26_example/data/mhw_mask_north_atlantic_final.nc'
oisst = xr.open_dataset(oisst_path,decode_times=False)

oisst_time = pd.date_range(start="1981-09-01", end="2026-08-17", freq="D")
oisst_time = np.array(date_range).astype('datetime64[D]')
oisst
# Out:
# <xarray.Dataset> Size: 1GB
# Dimensions:   (time: 16422, lat: 260, lon: 332)
# Coordinates:
#   * time      (time) int64 131kB -9223372036854775806 ... -9223372036854775806
#   * lat       (lat) float32 1kB 0.125 0.375 0.625 0.875 ... 64.38 64.62 64.88
#   * lon       (lon) float32 1kB 277.1 277.4 277.6 277.9 ... 359.4 359.6 359.9
# Data variables:
#     mhw_mask  (time, lat, lon) int8 1GB ...

# %%
XX_MHW, YY_MHW = np.meshgrid(oisst.lon.values, oisst.lat.values)
points = (XX_MHW.flatten(), YY_MHW.flatten())

mhw = griddata(points, oisst.mhw_mask.values[-1,:,:].flatten(), 
               (XX_SOCA, YY_SOCA), method='nearest').reshape(XX_SOCA.shape)
mhw = mhw.reshape(XX_SOCA.shape)

# %%
plt.pcolormesh(XX_SOCA, YY_SOCA, mhw, vmin =0, vmax = 1)
plt.colorbar()

# %%
np.unique(oisst.mhw_mask.values)
# Out:
# array([-127], dtype=int8)

# %%
# Subset OISST by year
yr_inds = np.where((oisst_time >= np.datetime64(str(year)+'-01-01')) & (oisst_time <= np.datetime64(str(year)+'-12-31')))[0]

oisst_subset = oisst.isel(time = yr_inds)
# Out:
# <xarray.Dataset> Size: 32MB
# Dimensions:   (time: 365, lat: 260, lon: 332)
# Coordinates:
#   * time      (time) int64 3kB -9223372036854775806 ... -9223372036854775806
#   * lat       (lat) float32 1kB 0.125 0.375 0.625 0.875 ... 64.38 64.62 64.88
#   * lon       (lon) float32 1kB 277.1 277.4 277.6 277.9 ... 359.4 359.6 359.9
# Data variables:
#     mhw_mask  (time, lat, lon) int8 32MB ...

# %%
np.array(date_range).astype('datetime64[D]')
# Out:
# array(['1981-09-01', '1981-09-02', '1981-09-03', ..., '2026-08-15',
#        '2026-08-16', '2026-08-17'], shape=(16422,), dtype='datetime64[D]')
